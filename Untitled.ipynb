# %%
import pandas as pd
df = pd.read_csv('test_0.csv')
df.plot.scatter(0, 1, 1.5)
df.plot.scatter(0, 2, 1.5)
df.plot.scatter(0, 3, 1.5)
# Out:
# <Axes: xlabel='dd', ylabel='active'>

# %%
df[df.captured >= 1].head(1)
# Out:
#       dd  captured  population  active
# 161  161         1         114     114

# %%
df[df.population >= 1].head(1)
# Out:
#       dd  captured  population  active
# 109  109         0           1       1
